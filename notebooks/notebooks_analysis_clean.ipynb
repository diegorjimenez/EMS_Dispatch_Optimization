# %% [markdown]
# # EMS Dispatch Optimization – Clean Analysis Notebook

# %% [markdown]
# This notebook loads data and calls the modularized model files.

# %%
import os
import pandas as pd

# %%
df = pd.read_csv('../data/allegheny_county_911_EMS_dispatches.csv')
df.head()
# Out:
#    _id                    call_id_hash service priority  \
# 0    1  000015F42010D7E9BFD0478A34A274     EMS       E4
# 1    2  0000B80868F29646B49B6BBEACF327     EMS       E3
# 2    3  000144D3D698BD201ADA401DB80C22     EMS       E5
# 3    4  00027A35111A3580959D7A51E11A6B     EMS       E3
# 4    5  0002E6494A455866F44A1ECE8426D7     EMS       E2
#
#                                        priority_desc call_quarter  call_year  \
# 0  EMS Basic Life Support Assistance response (i....           Q2       2019
# 1           EMS Standard Basic Life Support response           Q2       2017
# 2                       All administrative mark outs           Q2       2019
# 3           EMS Standard Basic Life Support response           Q4       2018
# 4        EMS Standard Advanced Life Support response           Q4       2016
#
#          description_short city_code    city_name         geoid  \
# 0                     FALL       WBG  WILKINSBURG  4.200356e+11
# ...

# %% [markdown]
# ## Run Supervised Models

# %%
# !python ../src/supervised/supervised_models.py
# Out:
# Traceback (most recent call last):
#   File "c:\Users\jimen\Documents\EMS Dispatch Optimization\src\supervised\supervised_models.py", line 10, in <module>
#     from sklearn.model_selection import train_test_split
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Run Unsupervised Models

# %%
# !python ../src/unsupervised/unsupervised_models.py
